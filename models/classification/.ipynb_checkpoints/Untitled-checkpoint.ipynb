# %%
from scipy.io import arff
import pandas as pd
import os
import numpy as np
import missingno as msno

# ucitavanje podataka 
def load_data_sets():
    ds = []
    data_path = os.path.dirname(os.path.dirname(os.path.abspath(os.curdir)))
    data_path = os.path.join(data_path, 'data')
    files = sorted(os.listdir(data_path))
    
    atr_names = [f'X{i}' for i in range(1, 65)]
    atr_names.append('class')

    for file in files:
        full_file_path = os.path.join(data_path, file)
        print(full_file_path)
        data = arff.loadarff(full_file_path)
        df = pd.DataFrame(data[0])
        df.columns = atr_names
        ds.append(df)
    return ds
        
        
data_sets = load_data_sets()
data_sets[0].head()
# Out:
# /home/korisnik/Desktop/IstrazivanjePodataka/projekat/2023_Data_Mining_Polish_bankriptcy_Dataset/data/1year.arff
# /home/korisnik/Desktop/IstrazivanjePodataka/projekat/2023_Data_Mining_Polish_bankriptcy_Dataset/data/2year.arff
# /home/korisnik/Desktop/IstrazivanjePodataka/projekat/2023_Data_Mining_Polish_bankriptcy_Dataset/data/3year.arff
# /home/korisnik/Desktop/IstrazivanjePodataka/projekat/2023_Data_Mining_Polish_bankriptcy_Dataset/data/4year.arff
# /home/korisnik/Desktop/IstrazivanjePodataka/projekat/2023_Data_Mining_Polish_bankriptcy_Dataset/data/5year.arff
#          X1       X2       X3      X4       X5       X6        X7       X8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# ...

# %%
# prebacivanje klasa u tip int
for i in range(len(data_sets)):
    column = getattr(data_sets[i], 'class')
    data_sets[i]['class'] = column.astype(np.int32)

data_sets[1].head()
# Out:
#          X1       X2        X3      X4      X5        X6       X7       X8  \
# 0  0.202350  0.46500  0.240380  1.5171 -14.547  0.510690  0.25366  0.91816
# 1  0.030073  0.59563  0.186680  1.3382 -37.859 -0.000319  0.04167  0.67890
# 2  0.257860  0.29949  0.665190  3.2211  71.799  0.000000  0.31877  2.33200
# 3  0.227160  0.67850  0.042784  1.0828 -88.212  0.000000  0.28505  0.47384
# 4  0.085443  0.38039  0.359230  1.9444  21.731  0.187900  0.10823  1.37140
#
#         X9      X10  ...      X56       X57      X58      X59     X60  \
# 0  1.15190  0.42695  ...  0.13184  0.473950  0.86816  0.00024  8.5487
# 1  0.32356  0.40437  ...  0.12146  0.074369  0.87235  0.00000  1.5264
# 2  1.67620  0.69841  ...  0.16499  0.369210  0.81614  0.00000  4.3325
# 3  1.32410  0.32150  ...  0.29358  0.706570  0.78617  0.48456  5.2309
# 4  1.11260  0.52167  ...  0.10124  0.163790  0.89876  0.00000  5.7035
#
#        X61      X62      X63      X64  class
# 0  5.16550  107.740  3.38790   5.3440      0
# ...

# %%
# rad sa nedostajucim vrednostima
# izbacivanjem gubimo oko 50% podataka i time gubimo znacajan deo informacija

missing_data = []

for data_set in data_sets:
    len1 = len(data_set)
    len2 = len(data_set.dropna())
    ratio = len2 / len1
    missing_data.append([len1, len2, ratio])
    
missing_data = pd.DataFrame(np.array(missing_data), columns=['total', 'missing value', 'data loss'],
                        index=[f'{i} year' for i in range(1, 6)])

# %%
missing_data
# Out:
#           total  missing value  data loss
# 1 year   7027.0         3194.0   0.454533
# 2 year  10173.0         4088.0   0.401848
# 3 year  10503.0         4885.0   0.465105
# 4 year   9792.0         4769.0   0.487030
# 5 year   5910.0         3031.0   0.512860

# %%
# sve dataframe-ove spajamo u jedan
union = data_sets[0]

for i in range(1, len(data_sets)):
    union = union.append(data_sets[i])

len(union)
union
# Out:
# /tmp/ipykernel_9558/2715339023.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   union = union.append(data_sets[i])
# /tmp/ipykernel_9558/2715339023.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   union = union.append(data_sets[i])
# /tmp/ipykernel_9558/2715339023.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   union = union.append(data_sets[i])
#             X1       X2        X3       X4        X5       X6        X7  \
# 0     0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1     0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2     0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# ...

# %%
# vizualizacija nedostajucih vrednosti
# udeono najvise atribut 37 sadrzi nedostajucih vrednosti, posmatrati i atribut 21

for data_set in data_sets:
    msno.matrix(data_set, labels=True, figsize=(40, 20))

# %%
for i, data_set in enumerate(data_sets):
    print(data_set['X37'].isna().sum() / len(data_set))
# Out:
# 0.3899245766329871
# 0.4441167797109997
# 0.45091878510901645
# 0.4536356209150327
# 0.4311336717428088
